# %%
name=input("enter a word:")
for i in name:
    if i=="a":
        x=1
        while x<7:
            if x==1:
                print("  ** ")
            elif x==2 or x==3:
                print("*    *")
            elif x==4:
                print("******")
            elif x==5:
                print("*    *")
            elif x==6:
                print("*    *")
            x=x+1
    elif i=="b":
        x=1
        while x<6:
            if x==1:
                print("*****")
            elif x==2 :
                print("*    *")
            elif x==3:
                print("*****")
            elif x==4  :
                print("*    *")
            elif x==5:
                print("*****")
            x=x+1
    elif i=="c":
        x=1
        while x<6:
            if x==1:
                print("*****")
            elif x==2 :
                print("*")
            elif x==3:
                print("*")
            elif x==4  :
                print("*")
            elif x==5:
                print("*****",sep="@")
            x=x+1
    elif i=="d":
        x=1
        while x<6:
            if x==1:
                print("*****")
            elif x==2 :
                print("*    *")
            elif x==3:
                print("*     *")
            elif x==4  :
                print("*    *")
            elif x==5:
                print("*****")
            x=x+1
    elif i=="e":
        x=1
        while x<6:
            if x==1:
                print("*****")
            elif x==2 :
                print("*    ")
            elif x==3:
                print("*****")
            elif x==4  :
                print("*    ")
            elif x==5:
                print("*****")
            x=x+1
    elif i=="f":
        x=1
        while x<6:
            if x==1:
                print("*****")
            elif x==2 :
                print("*    ")
            elif x==3:
                print("*****")
            elif x==4  :
                print("*    ")
            elif x==5:
                print("*")
            x=x+1
    elif i=="g":
        x=1
        while x<6:
            if x==1:
                print("*****")
            elif x==2 :
                print("*    ")
            elif x==3:
                print("*  **** ")
            elif x==4  :
                print("*   * *")
            elif x==5:
                print("***** *")
            x=x+1
    elif i=="h":
        for x in range(6):
            if x==1:
                print("*    *")
            elif x==2 :
                print("*    *")
            elif x==3:
                print("******")
            elif x==4  :
                print("*    *")
            elif x==5:
                print("*    *")
    elif i=="i":
        x=1
        while x<6:
            if x==1:
                print("*******")
            elif x==2 :
                print("   *    ")
            elif x==3:
                print("   * ")
            elif x==4  :
                print("   *")
            elif x==5:
                print("*******")
            x=x+1
    elif i=="j":
        x=1
        while x<6:
            if x==1:
                print("*******")
            elif x==2 :
                print("   *    ")
            elif x==3:
                print("   * ")
            elif x==4  :
                print("   *")
            elif x==5:
                print("****")
            x=x+1
    elif i=="k":
        x=1
        while x<6:
            if x==1:
                print("*  *")
            elif x==2 :
                print("* *  ")
            elif x==3:
                print("**")
            elif x==4  :
                print("* * ")
            elif x==5:
                print("*   *")
            x=x+1
    elif i=="l":
        x=1
        while x<6:
            if x==1:
                print("*  ")
            elif x==2 :
                print("*   ")
            elif x==3:
                print("*")
            elif x==4  :
                print("*  ")
            elif x==5:
                print("******* ")
            x=x+1
    elif i=="m":
        x=1
        while x<6:
            if x==1: 
                print("**        **")
            elif x==2 :
                print("*   *   *  *")
            elif x==3:
                print("*     *    *")
            elif x==4  : 
                print("*          *")
            elif x==5: 
                print("*          * ")
            x=x+1
    elif i=="n":
        x=1
        while x<6:
            if x==1: 
                print("**          *")
            elif x==2 : 
                print("*   *       *")
            elif x==3:
                print("*     *     *")
            elif x==4  : 
                print("*        *  *")
            elif x==5: 
                print("*          ** ")
            x=x+1
    elif i=="o":
        x=1
        while x<6:
            if x==1: 
                print(" ******")
            elif x==2 : 
                print("*      *")
            elif x==3:
                print("*      *")
            elif x==4  : 
                print("*      *")
            elif x==5: 
                print(" ******")
            x=x+1
    elif i=="p":
        x=1
        while x<6:
            if x==1: 
                print("*******")
            elif x==2 : 
                print("*      *")
            elif x==3:
                print("*******")
            elif x==4  : 
                print("*      ")
            elif x==5: 
                print("*")
            x=x+1
    elif i=="q":
        x=1
        while x<6:
            if x==1: 
                print(" ******")
            elif x==2 : 
                print("*      *")
            elif x==3:
                print("*  **  *")
            elif x==4  : 
                print("*     **")
            elif x==5: 
                print(" ******  **")
            x=x+1
    elif i=="r":
        x=1
        while x<6:
            if x==1: 
                print("*******")
            elif x==2 : 
                print("*      *")
            elif x==3:
                print("*******")
            elif x==4  : 
                print("*      *")
            elif x==5: 
                print("*       *")
            x=x+1
    elif i=="s":
        x=1
        while x<6:
            if x==1: 
                print("*******")
            elif x==2 : 
                print("*      ")
            elif x==3:
                print("*******")
            elif x==4  : 
                print("       *")
            elif x==5: 
                print("*******")
            x=x+1
    elif i=="t":
        x=1
        while x<6:
            if x==1: 
                print("*********")
            elif x==2 : 
                print("    *")
            elif x==3:
                print("    *")
            elif x==4  : 
                print("    *")
            elif x==5: 
                print("    *")
            x=x+1
    elif i=="u":
        x=1
        while x<6:
            if x==1: 
                print("*      *")
            elif x==2 : 
                print("*      *")
            elif x==3:
                print("*      *")
            elif x==4  : 
                print("*      *")
            elif x==5: 
                print("********")
            x=x+1
    elif i=="v":
        x=1
        while x<6:
            if x==1: 
                print("*         *")
            elif x==2 : 
                print(" *       *")
            elif x==3: 
                print("  *     *")
            elif x==4  : 
                print("   *   *")
            elif x==5: 
                print("     *")
            x=x+1
    elif i=="w":
        x=1
        while x<6:
            if x==1: 
                print("*       *       *")
            elif x==2 :
                print(" *     * *     *")
            elif x==3: 
                print("  *   *   *   *")
            elif x==4  : 
                print("   * *     * *")
            elif x==5: 
                print("    *       *")
            x=x+1
    elif i=="x":
        x=1
        while x<6:
            if x==1: 
                print("*      *")
            elif x==2 : 
                print("  *   *")
            elif x==3:
                print("    *      ")
            elif x==4  : 
                print("  *   *")
            elif x==5: 
                print("*       *")
            x=x+1
    elif i=="y":
        x=1
        while x<6:
            if x==1: 
                print("*      *")
            elif x==2 : 
                print("  *   *")
            elif x==3:
                print("    *      ")
            elif x==4  : 
                print("  *   ")
            elif x==5: 
                print("*       ")
            x=x+1
    elif i=="z":
        x=1
        while x<6:
            if x==1: 
                print("*******")
            elif x==2 : 
                print("     *")
            elif x==3:
                print("   *")
            elif x==4  : 
                print(" *      ")
            elif x==5: 
                print("*******")
            x=x+1
# Out:
# enter a word:aishwarya
#   **
# *    *
# *    *
# ******
# *    *
# *    *
# *******
#    *
#    *
#    *
# *******
# *******
# *
# *******
#        *
# *******
# *    *
# *    *
# ******
# *    *
# *    *
# *       *       *
#  *     * *     *
#   *   *   *   *
#    * *     * *
#     *       *
#   **
# *    *
# *    *
# ******
# *    *
# *    *
# *******
# *      *
# *******
# *      *
# *       *
# *      *
#   *   *
#     *
#   *
# *
#   **
# *    *
# *    *
# ******
# *    *
# *    *
